# %%
# !pip install qiskit[visualization]
! pip install quantuminspire
# Out:
# Requirement already satisfied: qiskit[visualization] in /opt/conda/lib/python3.9/site-packages (0.34.1)
# Requirement already satisfied: qiskit-ignis==0.7.0 in /opt/conda/lib/python3.9/site-packages (from qiskit[visualization]) (0.7.0)
# Requirement already satisfied: qiskit-terra==0.19.1 in /opt/conda/lib/python3.9/site-packages (from qiskit[visualization]) (0.19.1)
# Requirement already satisfied: qiskit-aer==0.10.2 in /opt/conda/lib/python3.9/site-packages (from qiskit[visualization]) (0.10.2)
# Requirement already satisfied: qiskit-ibmq-provider==0.18.3 in /opt/conda/lib/python3.9/site-packages (from qiskit[visualization]) (0.18.3)
# Requirement already satisfied: pydot in /opt/conda/lib/python3.9/site-packages (from qiskit[visualization]) (1.4.2)
# Requirement already satisfied: pillow>=4.2.1 in /opt/conda/lib/python3.9/site-packages (from qiskit[visualization]) (9.0.0)
# Requirement already satisfied: pylatexenc>=1.4 in /opt/conda/lib/python3.9/site-packages (from qiskit[visualization]) (2.10)
# Requirement already satisfied: matplotlib>=2.1 in /opt/conda/lib/python3.9/site-packages (from qiskit[visualization]) (3.5.1)
# Requirement already satisfied: seaborn>=0.9.0 in /opt/conda/lib/python3.9/site-packages (from qiskit[visualization]) (0.11.2)
# Requirement already satisfied: pygments>=2.4 in /opt/conda/lib/python3.9/site-packages (from qiskit[visualization]) (2.10.0)
# Requirement already satisfied: ipywidgets>=7.3.0 in /opt/conda/lib/python3.9/site-packages (from qiskit[visualization]) (7.6.5)
# Requirement already satisfied: numpy>=1.16.3 in /opt/conda/lib/python3.9/site-packages (from qiskit-aer==0.10.2->qiskit[visualization]) (1.20.3)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.9/site-packages (from qiskit-aer==0.10.2->qiskit[visualization]) (1.7.3)
# Requirement already satisfied: websocket-client>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.18.3->qiskit[visualization]) (1.2.3)
# Requirement already satisfied: urllib3>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.18.3->qiskit[visualization]) (1.26.7)
# Requirement already satisfied: requests>=2.19 in /opt/conda/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.18.3->qiskit[visualization]) (2.26.0)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /opt/conda/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.18.3->qiskit[visualization]) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.18.3->qiskit[visualization]) (2.8.2)
# Requirement already satisfied: setuptools>=40.1.0 in /opt/conda/lib/python3.9/site-packages (from qiskit-ignis==0.7.0->qiskit[visualization]) (59.4.0)
# Requirement already satisfied: retworkx>=0.8.0 in /opt/conda/lib/python3.9/site-packages (from qiskit-ignis==0.7.0->qiskit[visualization]) (0.11.0)
# Requirement already satisfied: psutil>=5 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.19.1->qiskit[visualization]) (5.8.0)
# Requirement already satisfied: symengine>=0.8 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.19.1->qiskit[visualization]) (0.8.1)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.19.1->qiskit[visualization]) (1.9)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.19.1->qiskit[visualization]) (0.3.4)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.19.1->qiskit[visualization]) (1.1.1)
# Requirement already satisfied: python-constraint>=1.4 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.19.1->qiskit[visualization]) (1.4.0)
# Requirement already satisfied: ply>=3.10 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.19.1->qiskit[visualization]) (3.11)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.19.1->qiskit[visualization]) (3.5.0)
# Requirement already satisfied: ipython>=4.0.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets>=7.3.0->qiskit[visualization]) (7.30.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets>=7.3.0->qiskit[visualization]) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.9/site-packages (from ipywidgets>=7.3.0->qiskit[visualization]) (6.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.9/site-packages (from ipywidgets>=7.3.0->qiskit[visualization]) (5.1.1)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets>=7.3.0->qiskit[visualization]) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets>=7.3.0->qiskit[visualization]) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets>=7.3.0->qiskit[visualization]) (1.0.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.1->qiskit[visualization]) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.1->qiskit[visualization]) (4.29.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.1->qiskit[visualization]) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.1->qiskit[visualization]) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.1->qiskit[visualization]) (3.0.6)
# Requirement already satisfied: pandas>=0.23 in /opt/conda/lib/python3.9/site-packages (from seaborn>=0.9.0->qiskit[visualization]) (1.4.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in /opt/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in /opt/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (7.1.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /opt/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (0.1.3)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.3.0->qiskit[visualization]) (5.1.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.2.0)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.3.0->qiskit[visualization]) (3.0.24)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.3.0->qiskit[visualization]) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.18.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.3.0->qiskit[visualization]) (4.2.1)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.3.0->qiskit[visualization]) (4.9.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=0.23->seaborn>=0.9.0->qiskit[visualization]) (2021.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.18.3->qiskit[visualization]) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.18.3->qiskit[visualization]) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.18.3->qiskit[visualization]) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.18.3->qiskit[visualization]) (2.0.9)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /opt/conda/lib/python3.9/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.18.3->qiskit[visualization]) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in /opt/conda/lib/python3.9/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.18.3->qiskit[visualization]) (36.0.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from stevedore>=3.0.0->qiskit-terra==0.19.1->qiskit[visualization]) (5.8.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.9/site-packages (from sympy>=1.3->qiskit-terra==0.19.1->qiskit[visualization]) (1.2.1)
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (6.4.6)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.9/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.18.3->qiskit[visualization]) (1.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.3.0->qiskit[visualization]) (21.2.0)
# Requirement already satisfied: pyzmq>=13 in /opt/conda/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (19.0.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /opt/conda/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (1.5.4)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (0.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.12.1)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (6.3.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.12.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (1.8.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (21.1.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (3.0.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.2.5)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.18.3->qiskit[visualization]) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (2.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.5.9)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.1.2)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.8.4)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.5.1)
# Requirement already satisfied: quantuminspire in /opt/conda/lib/python3.9/site-packages (1.7.0)
# Requirement already satisfied: matplotlib>=2.1 in /opt/conda/lib/python3.9/site-packages (from quantuminspire) (3.5.1)
# Requirement already satisfied: sklearn in /opt/conda/lib/python3.9/site-packages (from quantuminspire) (0.0)
# Requirement already satisfied: jupyter in /opt/conda/lib/python3.9/site-packages (from quantuminspire) (1.0.0)
# Requirement already satisfied: coreapi>=2.3.3 in /opt/conda/lib/python3.9/site-packages (from quantuminspire) (2.3.3)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.9/site-packages (from quantuminspire) (1.20.3)
# Requirement already satisfied: nbimporter in /opt/conda/lib/python3.9/site-packages (from quantuminspire) (0.3.4)
# Requirement already satisfied: pylatexenc in /opt/conda/lib/python3.9/site-packages (from quantuminspire) (2.10)
# Requirement already satisfied: coverage>=4.5.1 in /opt/conda/lib/python3.9/site-packages (from quantuminspire) (6.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from coreapi>=2.3.3->quantuminspire) (2.26.0)
# Requirement already satisfied: itypes in /opt/conda/lib/python3.9/site-packages (from coreapi>=2.3.3->quantuminspire) (1.2.0)
# Requirement already satisfied: coreschema in /opt/conda/lib/python3.9/site-packages (from coreapi>=2.3.3->quantuminspire) (0.0.4)
# Requirement already satisfied: uritemplate in /opt/conda/lib/python3.9/site-packages (from coreapi>=2.3.3->quantuminspire) (4.1.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.1->quantuminspire) (21.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.1->quantuminspire) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.1->quantuminspire) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.1->quantuminspire) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.1->quantuminspire) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.1->quantuminspire) (4.29.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=2.1->quantuminspire) (9.0.0)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.9/site-packages (from jupyter->quantuminspire) (6.6.0)
# Requirement already satisfied: jupyter-console in /opt/conda/lib/python3.9/site-packages (from jupyter->quantuminspire) (6.4.0)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.9/site-packages (from jupyter->quantuminspire) (6.3.0)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.9/site-packages (from jupyter->quantuminspire) (7.6.5)
# Requirement already satisfied: notebook in /opt/conda/lib/python3.9/site-packages (from jupyter->quantuminspire) (6.4.6)
# Requirement already satisfied: qtconsole in /opt/conda/lib/python3.9/site-packages (from jupyter->quantuminspire) (5.2.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.9/site-packages (from sklearn->quantuminspire) (1.0.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.1->quantuminspire) (1.16.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from coreschema->coreapi>=2.3.3->quantuminspire) (3.0.3)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /opt/conda/lib/python3.9/site-packages (from ipykernel->jupyter->quantuminspire) (0.1.3)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/lib/python3.9/site-packages (from ipykernel->jupyter->quantuminspire) (7.30.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /opt/conda/lib/python3.9/site-packages (from ipykernel->jupyter->quantuminspire) (6.1)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in /opt/conda/lib/python3.9/site-packages (from ipykernel->jupyter->quantuminspire) (5.1.1)
# Requirement already satisfied: jupyter-client<8.0 in /opt/conda/lib/python3.9/site-packages (from ipykernel->jupyter->quantuminspire) (7.1.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from ipykernel->jupyter->quantuminspire) (1.5.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->jupyter->quantuminspire) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->jupyter->quantuminspire) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->jupyter->quantuminspire) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->jupyter->quantuminspire) (1.0.2)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.9/site-packages (from jupyter-console->jupyter->quantuminspire) (2.10.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from jupyter-console->jupyter->quantuminspire) (3.0.24)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.9/site-packages (from nbconvert->jupyter->quantuminspire) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.9/site-packages (from nbconvert->jupyter->quantuminspire) (0.5.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.9/site-packages (from nbconvert->jupyter->quantuminspire) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.9/site-packages (from nbconvert->jupyter->quantuminspire) (0.1.2)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.9/site-packages (from nbconvert->jupyter->quantuminspire) (4.1.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.9/site-packages (from nbconvert->jupyter->quantuminspire) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.9/site-packages (from nbconvert->jupyter->quantuminspire) (0.8.4)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.9/site-packages (from nbconvert->jupyter->quantuminspire) (4.9.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.9/site-packages (from nbconvert->jupyter->quantuminspire) (0.5.9)
# Requirement already satisfied: nest-asyncio>=1.5 in /opt/conda/lib/python3.9/site-packages (from notebook->jupyter->quantuminspire) (1.5.4)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.9/site-packages (from notebook->jupyter->quantuminspire) (0.12.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.9/site-packages (from notebook->jupyter->quantuminspire) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.9/site-packages (from notebook->jupyter->quantuminspire) (0.12.1)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.9/site-packages (from notebook->jupyter->quantuminspire) (19.0.2)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.9/site-packages (from notebook->jupyter->quantuminspire) (21.1.0)
# Requirement already satisfied: qtpy in /opt/conda/lib/python3.9/site-packages (from qtconsole->jupyter->quantuminspire) (2.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->coreapi>=2.3.3->quantuminspire) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->coreapi>=2.3.3->quantuminspire) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->coreapi>=2.3.3->quantuminspire) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests->coreapi>=2.3.3->quantuminspire) (2.0.9)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.9/site-packages (from scikit-learn->sklearn->quantuminspire) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn->sklearn->quantuminspire) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn->sklearn->quantuminspire) (3.0.0)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->quantuminspire) (0.18.1)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->quantuminspire) (0.2.0)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->quantuminspire) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->quantuminspire) (4.8.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->quantuminspire) (5.1.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->quantuminspire) (59.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->coreschema->coreapi>=2.3.3->quantuminspire) (2.0.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->quantuminspire) (4.2.1)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->quantuminspire) (0.2.5)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.9/site-packages (from terminado>=0.8.3->notebook->jupyter->quantuminspire) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter->quantuminspire) (1.15.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.9/site-packages (from bleach->nbconvert->jupyter->quantuminspire) (0.5.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->quantuminspire) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->quantuminspire) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->quantuminspire) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->quantuminspire) (21.2.0)

# %%
import numpy as np
# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, execute, transpile, Aer, IBMQ
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from random import getrandbits
import binascii
import time
import os
from IPython.display import display

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute
from qiskit.tools.visualization import plot_histogram, circuit_drawer

from quantuminspire.credentials import get_authentication
from quantuminspire.qiskit import QI
from getpass import getpass

QI_URL = os.getenv('QI_URL', 'https://api.quantum-inspire.com/')

def get_authentication():
    """Gets the authentication for connecting to the
       Quantum Inspire API.
    """
    email = "bolivares8090@gmail.com"
    password = "RNP25SeOmHlt7sZyrMx1"
    return [email, password] 


if 'authentication' not in vars().keys():
    authentication = get_authentication()
QI.set_authentication_details(*authentication)
qi_backend = QI.get_backend('Spin-2')

# %%
def encrypt_message(unencrypted_string, key):
    # Convert ascii string to binary string
    bits = bin(int(binascii.hexlify(unencrypted_string.encode('utf-8', 'surrogatepass')), 16))[2:]
    bitstring = bits.zfill(8 * ((len(bits) + 7) // 8))
    # created the encrypted string using the key
    encrypted_string = ""
    for i in range(len(bitstring)):
        encrypted_string += str( (int(bitstring[i])^ int(key[i])) )
    return encrypted_string
    
def decrypt_message(encrypted_bits, key):
    # created the unencrypted string using the key
    unencrypted_bits = ""
    for i in range(len(encrypted_bits)):
        unencrypted_bits += str( (int(encrypted_bits[i])^ int(key[i])) )
    # Convert bitstring into
    i = int(unencrypted_bits, 2)
    hex_string = '%x' % i
    n = len(hex_string)
    bits = binascii.unhexlify(hex_string.zfill(n + (n & 1)))
    unencrypted_string = bits.decode('utf-8', 'surrogatepass')
    return unencrypted_string

# %%
message = input("Please enter a message: ")
print("Original Message:", message)
bits = bin(int(binascii.hexlify(message.encode('utf-8', 'surrogatepass')), 16))[2:]
bitstring = bits.zfill(8 * ((len(bits) + 7) // 8))

alice_bits = [] #This list will store Alice's bits
for i in range(3*len(bitstring)):  
    alice_bits.append(str(getrandbits(1))) 

alice_bases = [] # List to store Alice's bases
for i in range(3*len(bitstring)):
    base = getrandbits(1)
    if base == 0:
        alice_bases.append("Z")
    else:
        alice_bases.append("X")

encoded_qubits = []
for i in range(3*len(bitstring)):
    qc = QuantumCircuit(1,1)
    if alice_bases[i] == "Z":
        if alice_bits[i] == '0':
            pass # We want nothing to happen here - the qubit is already in the state |0>

        elif alice_bits[i] == '1':
            qc.x(0) # Applying an X gate to change the qubit state to |1>
            
    elif alice_bases[i] == "X":
        if alice_bits[i] == '0':
            qc.h(0) # Applying an H gate to change the qubit state to |+>
        elif alice_bits[i] == '1':
            qc.x(0) # Applying an X and H gate to change the qubit state to |->
            qc.h(0)
            
    encoded_qubits.append(qc) # Adding the qubit with the right state to the list of qubits that Alice will send Bob

bob_bases = []
for i in range(3*len(bitstring)):
    bit = getrandbits(1)
    if bit == 0:
        bob_bases.append("Z")
    else:
        bob_bases.append("X")

bob_bits = [] # List of Bob's bits generated from the results of Bob's measurements
    
for i in range(3*len(bitstring)):
    qc = encoded_qubits[i]
        
    if bob_bases[i] == "Z": # Bob's basis is Z
            qc.measure(0,0) #Code to measure in the Z basis
        

    elif bob_bases[i] == "X": #The case that bob_bases[i] is X
            qc.h(0) #WRITE CODE HERE: Bob needs to add a gate here to correctly measure in the X basis. Which gate is this?  
            qc.measure(0,0)  #Measurement in the X basis
            
            
      # Now that the measurements have been added to the circuit, let's run them.
    
    
    job = execute(qc, backend = Aer.get_backend("qasm_simulator"), shots = 1) 
    results = job.result()
    counts = results.get_counts()
    measured_bit = max(counts, key=counts.get)

        # Append measured bit to Bob's measured bitstring
    bob_bits.append(measured_bit) 

agreeing_indices = []
    
for i in range(3*len(bitstring)):
    if alice_bases[i]==bob_bases[i]:
        agreeing_indices.append(i)

alice_key = []
for index in agreeing_indices:
    alice_key.append(alice_bits[index])

bob_key = []
for index in agreeing_indices:
    bob_key.append(bob_bits[index])

# Call the function encrypt_message with the right inputs
encrypted_message = encrypt_message(message,alice_key)
print("Encrypted message:", encrypted_message)

# Call the function deencrypt_message with the right inputs
decrypted_message = decrypt_message(encrypted_message, bob_key)
print("Decrypted message:", decrypted_message)
# Out:
#   Input In [4]
#     job = execute(qc, backend = Aer.("qasm_simulator"), shots = 1)
#                                     ^
# SyntaxError: invalid syntax
